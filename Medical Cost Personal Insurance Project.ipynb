# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
med_data=pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Medical%20Cost%20Insurance/medical_cost_insurance.csv")

# %%
med_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
med_data.shape
# Out:
# (1338, 7)

# %%
med_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
med_data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
med_data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
med_data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
plt.figure(figsize=(5,5))
style.use("ggplot")
sns.countplot(x="sex",data = med_data)
plt.title("Gender Distribution")
plt.show()

# %%
sns.countplot(x="smoker",data= med_data)
plt.title("Smoker")
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x="region",data= med_data)
plt.title("Region")
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.barplot(x="region",y="charges",data=med_data)
plt.title("Cost Vs Region")
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.barplot(x="smoker",y="charges",data=med_data)
plt.title("Charges for Smoker")
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x="sex",y="charges",hue="smoker",data=med_data)
plt.title("Charges as per Gender for Smoker")
plt.show()

# %%
fig, axes = plt.subplots(1,3, figsize=(13,5),sharey=True)
fig.suptitle("Visalizing Categorical Columns")
sns.boxenplot(x="smoker",y="charges",data=med_data,ax=axes[0])
sns.boxenplot(x="smoker",y="charges",data=med_data,ax=axes[1])
sns.boxenplot(x="smoker",y="charges",data=med_data,ax=axes[2])
plt.show()

# %%
med_data[["age","bmi","children","charges"]].hist(bins=30,figsize=(10,10),color="green")
plt.show()

# %%
med_data['sex'] = med_data["sex"].apply({"male":0, "female":1}.get)
med_data["smoker"] = med_data['smoker'].apply({"yes":1,"no":0}.get)
med_data["region"]= med_data["region"].apply({"southwest":1,"southeast":2,"northwest":3,"northeast":4}.get)

# %%
med_data.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    1  27.900         0       1  southwest  16884.92400
# 1   18    0  33.770         1       0  southeast   1725.55230
# 2   28    0  33.000         3       0  southeast   4449.46200
# 3   33    0  22.705         0       0  northwest  21984.47061
# 4   32    0  28.880         0       0  northwest   3866.85520

# %%
plt.figure(figsize=(10,7))
sns.heatmap(med_data.corr(),annot=True)
plt.show()
# Out:
# C:\Users\AM\AppData\Local\Temp\ipykernel_3036\1505853487.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(med_data.corr(),annot=True)

# %%
x = med_data.drop(["charges","sex"],axis=1)
y = med_data.charges

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2)
print("x_train shape:",x_train.shape)
print("x_test shape:",x_train.shape)
print("y_train shape:",y_train.shape)
print("y_test shape:",y_test.shape)
# Out:
# x_train shape: (936, 5)
# x_test shape: (936, 5)
# y_train shape: (936,)
# y_test shape: (402,)

# %%
linrg = LinearRegression()

# %%
training_data_prediction=linrg(x_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 training_data_prediction=linrg(x_train)
#
# TypeError: 'LinearRegression' object is not callable

# %%
from sklearn.metrics import r2_score

# %%
print("R2 score:",(r2_score(y_test,pred)
# Out:
#   Cell In[46], line 1
#     print("R2 score:",(r2_score(y_test,pred)
#                                             ^
# SyntaxError: incomplete input
